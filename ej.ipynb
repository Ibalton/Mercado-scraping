# %%
from base.mercadolibre import MercadoLibre

# %%
queries = {
    "PS4": 8,
    "PS5": 8,
    "XBOX": 2,
}
mercado = MercadoLibre(queries=queries)

# %%
await mercado.scrape()
# Out:
# 100%|██████████| 18/18 [00:03<00:00,  5.07it/s]
#                                                  title      price  \
# 0    Playstation 5 Slim 1tb + Ea Fc 24 Fisico Ps5 N...  1399999.0
# 1    Playstation 5 Slim 1tb + Ea Fc 24 Fisico Ps5 N...  1769999.0
# 2                                     Ps5 Slim Standar  1000000.0
# 3           Ea Sports Fc 25 Ps5 Formato Físico Vemayme    99999.0
# 4           Ea Sports Fc 25 Ps5 Formato Físico Vemayme    72500.0
# ..                                                 ...        ...
# 615         Ea Sports Fc 25 Ps5 Formato Físico Vemayme   112999.0
# 616  Rise Of The Ronin Ps5 - Fisico - Playstation 5...   154999.0
# 617         Ea Sports Fc 25 Ps5 Formato Físico Vemayme    89999.0
# 618   Cubre Stick Premium Ps4 - Ps5 (el Par) Soy Gamer    12500.0
# 619                   Consola Ps5 Estándar Playstation   880000.0
#
#              ml_id                                                url
# ...
