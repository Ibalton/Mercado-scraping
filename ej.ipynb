# %%
from base.mercadolibre import MercadoLibre

# %%
queries = {
    "PS4": 8,
    "PS5": 8,
    "XBOX": 2,
}
mercado = MercadoLibre(queries=queries)

# %%
# !sqlacodegen postgresql://postgres:secret@localhost:5431/postgres --outfile=models.py
# Out:
# Using pgvector 0.4.0

# %%
# !pip install psycopg2-binary

# %%
from bs4 import BeautifulSoup
import requests

soup = BeautifulSoup(requests.get("https://listado.mercadolibre.com.ar/Xbox one_Desde_0_NoIndex_True").text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es-AR">
#  <head>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://data.mercadolibre.com" rel="preconnect"/>
#   <link href="https://http2.mlstatic.com" rel="preconnect"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://analytics.mercadolibre.com.ar" rel="preconnect"/>
#   <link href="https://analytics.mercadolibre.com" rel="preconnect"/>
#   <link href="https://www.google.com.ar" rel="preconnect"/>
#   <script nonce="XbFvX+5QHHFUBcCYFCMCGQ==" type="text/javascript">
# ...

# %%
soup.find("noscript").find("meta").attrs["content"].split("%2F")[-1].split("_")[0].replace("-", " ")
# Out:
# 'xbox one'
